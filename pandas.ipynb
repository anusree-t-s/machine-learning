# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
s = pd.Series([1,3,5,np.nan,6,8]) 
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range('20130101', periods=6)
dates
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2013-01-01 -0.363090 -0.451180 -0.510092 -0.607514
# 2013-01-02 -0.307327  0.270304 -0.051505 -1.427291
# 2013-01-03  0.708463 -0.735920 -0.380170 -1.187013
# 2013-01-04 -1.054841  0.906523  1.217991 -0.473066
# 2013-01-05 -0.630084  0.164823  0.475958 -1.222516
# 2013-01-06  0.617041 -0.959645  0.420525 -0.387322

# %%
df2 = pd.DataFrame({ 'A' : 1.,
                      'B' : pd.Timestamp('20130102'),
                        'C' : pd.Series(1,index=list(range(4)),dtype='float32'),
                        'D' : np.array([3] * 4,dtype='int32'),
                        'E' : pd.Categorical(["test","train","test","train"]),
                         'F' : 'foo' })
  

df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
 df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01 -0.363090 -0.451180 -0.510092 -0.607514
# 2013-01-02 -0.307327  0.270304 -0.051505 -1.427291
# 2013-01-03  0.708463 -0.735920 -0.380170 -1.187013
# 2013-01-04 -1.054841  0.906523  1.217991 -0.473066
# 2013-01-05 -0.630084  0.164823  0.475958 -1.222516

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2013-01-04 -1.054841  0.906523  1.217991 -0.473066
# 2013-01-05 -0.630084  0.164823  0.475958 -1.222516
# 2013-01-06  0.617041 -0.959645  0.420525 -0.387322

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.values
# Out:
# array([[-0.36308992, -0.45118019, -0.51009196, -0.60751386],
#        [-0.30732715,  0.270304  , -0.05150503, -1.42729128],
#        [ 0.70846335, -0.73591973, -0.38017007, -1.18701256],
#        [-1.05484122,  0.90652324,  1.21799114, -0.47306587],
#        [-0.6300842 ,  0.16482317,  0.47595814, -1.22251605],
#        [ 0.61704085, -0.95964461,  0.42052492, -0.38732249]])

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.171640 -0.134182  0.195451 -0.884120
# std    0.698839  0.704279  0.642658  0.445775
# min   -1.054841 -0.959645 -0.510092 -1.427291
# 25%   -0.563336 -0.664735 -0.298004 -1.213640
# 50%   -0.335209 -0.143179  0.184510 -0.897263
# 75%    0.385949  0.243934  0.462100 -0.506678
# max    0.708463  0.906523  1.217991 -0.387322

# %%
df.to_xarray()
# Out:
# <xarray.Dataset>
# Dimensions:  (index: 6)
# Coordinates:
#   * index    (index) datetime64[ns] 2013-01-01 2013-01-02 ... 2013-01-06
# Data variables:
#     A        (index) float64 -0.3631 -0.3073 0.7085 -1.055 -0.6301 0.617
#     B        (index) float64 -0.4512 0.2703 -0.7359 0.9065 0.1648 -0.9596
#     C        (index) float64 -0.5101 -0.05151 -0.3802 1.218 0.476 0.4205
#     D        (index) float64 -0.6075 -1.427 -1.187 -0.4731 -1.223 -0.3873

# %%
df.iloc[3]
# Out:
# A   -1.054841
# B    0.906523
# C    1.217991
# D   -0.473066
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.loc['20130101','A']
# Out:
# -0.3630899243363894

# %%
df.mean(1)
# Out:
# 2013-01-01   -0.482969
# 2013-01-02   -0.378955
# 2013-01-03   -0.398660
# 2013-01-04    0.149152
# 2013-01-05   -0.302955
# 2013-01-06   -0.077350
# Freq: D, dtype: float64

# %%
s = pd.Series([1,3,5,np.nan,6,8], index=dates).shift(2)
s
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %%
df.sub(s, axis='index')
# Out:
#                    A         B         C         D
# 2013-01-01       NaN       NaN       NaN       NaN
# 2013-01-02       NaN       NaN       NaN       NaN
# 2013-01-03 -0.291537 -1.735920 -1.380170 -2.187013
# 2013-01-04 -4.054841 -2.093477 -1.782009 -3.473066
# 2013-01-05 -5.630084 -4.835177 -4.524042 -6.222516
# 2013-01-06       NaN       NaN       NaN       NaN

# %%
df.apply(np.cumsum)
# Out:
#                    A         B         C         D
# 2013-01-01 -0.363090 -0.451180 -0.510092 -0.607514
# 2013-01-02 -0.670417 -0.180876 -0.561597 -2.034805
# 2013-01-03  0.038046 -0.916796 -0.941767 -3.221818
# 2013-01-04 -1.016795 -0.010273  0.276224 -3.694884
# 2013-01-05 -1.646879  0.154550  0.752182 -4.917400
# 2013-01-06 -1.029838 -0.805094  1.172707 -5.304722

# %%
df.apply(lambda x: x.max() - x.min())
# Out:
# A    1.763305
# B    1.866168
# C    1.728083
# D    1.039969
# dtype: float64
